# %% [markdown]
# <a href="https://colab.research.google.com/github/cxbxmxcx/GenReality/blob/master/GEN_9_Make_Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import glob
 
img_array = []
for filename in sorted(glob.glob('/content/images/*.png')):
    print(filename)    
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
# Out:
# /content/images/Pretty Woman Necklace_000001.png
# /content/images/Pretty Woman Necklace_000002.png
# /content/images/Pretty Woman Necklace_000003.png
# /content/images/Pretty Woman Necklace_000004.png
# /content/images/Pretty Woman Necklace_000005.png
# /content/images/Pretty Woman Necklace_000006.png
# /content/images/Pretty Woman Necklace_000007.png
# /content/images/Pretty Woman Necklace_000008.png
# /content/images/Pretty Woman Necklace_000009.png
# /content/images/Pretty Woman Necklace_000010.png
# /content/images/Pretty Woman Necklace_000011.png
# /content/images/Pretty Woman Necklace_000012.png
# /content/images/Pretty Woman Necklace_000013.png
# /content/images/Pretty Woman Necklace_000014.png
# /content/images/Pretty Woman Necklace_000015.png
# /content/images/Pretty Woman Necklace_000016.png
# /content/images/Pretty Woman Necklace_000017.png
# /content/images/Pretty Woman Necklace_000018.png
# /content/images/Pretty Woman Necklace_000019.png
# ...

# %%
movie = 'deepfakes.mp4'
#codecs
# Define the codec and create VideoWriter object
#fourcc = cv2.VideoWriter_fourcc(*'FFV1')
#fourcc = cv2.VideoWriter_fourcc(*'XVID')
#fourcc = cv2.VideoWriter_fourcc(*'DIVX')
#fourcc = cv2.VideoWriter_fourcc(*'DIV3')
fourcc = cv2.VideoWriter_fourcc('F','M','P','4')
#fourcc = cv2.VideoWriter_fourcc('D','I','V','X')
#fourcc = cv2.VideoWriter_fourcc('D','I','V','3')
#fourcc = cv2.VideoWriter_fourcc('F','F','V','1')
out = cv2.VideoWriter(movie,fourcc, 15, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()

# %%
from google.colab import files
files.download(movie)
