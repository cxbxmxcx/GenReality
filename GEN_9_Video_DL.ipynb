# %% [markdown]
# <a href="https://colab.research.google.com/github/cxbxmxcx/GenReality/blob/master/GEN_9_Video_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade youtube-dl
# Out:
# Collecting youtube-dl
#   Downloading https://files.pythonhosted.org/packages/a5/9e/41c2b27e5ef6b28caacdfea46ad84c47f836e3a5034e3a48ee9050c10761/youtube_dl-2021.1.24.1-py2.py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 5.6MB/s
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.1.24.1

# %%
#@title SELECT VIDEO
video = "Pretty Woman" #@param ["Elf", "Zoolander", "Schitts Creek","Pretty Woman","Avengers","Anchorman"]
from __future__ import unicode_literals
import youtube_dl

videos = { "Elf" : { "url" : 'https://www.youtube.com/watch?v=3Eto6DU_2oI'},
             "Zoolander" : { "url" : "https://www.youtube.com/watch?v=KeX9BXnD6D4"},
             "Schitts Creek" : { "url" : "https://www.youtube.com/watch?v=hg1Uk60rBsc"},
             "Pretty Woman" : { "url" : "https://youtu.be/watch?v=sNYalWdtPSA"},
             "Avengers" : { "url" : "https://www.youtube.com/watch?v=JyyGJk51n-0"},
             "Anchorman" : { "url" : "https://www.youtube.com/watch?v=88zGzznpnis"},
            } 
video_url = videos[video]['url']

download_options = {}
download = youtube_dl.YoutubeDL(download_options)
info_dict = download.extract_info(video_url, download=False)
formats = info_dict.get('formats',None)

for f in formats:    
  if f.get('format_note',None) == '480p':        
    url = f.get('url',None)  

print(url)
# Out:
# [generic] watch?v=sNYalWdtPSA: Requesting header
# [redirect] Following redirect to https://www.youtube.com/watch?v=sNYalWdtPSA&v=watch&feature=youtu.be
# [youtube] sNYalWdtPSA: Downloading webpage
# [youtube] sNYalWdtPSA: Downloading js player 7bc032d0
# [youtube] sNYalWdtPSA: Downloading js player 7bc032d0
# https://r4---sn-5uaezn6y.googlevideo.com/videoplayback?expire=1612129831&ei=x9EWYIGOEsuN2LYPpNGVoAk&ip=34.74.130.200&id=o-AFDtgqa1ZXAtx_ne1VoEXgTRiht6FqXbh4a-tEyCi9u3&itag=135&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278&source=youtube&requiressl=yes&mh=3e&mm=31%2C26&mn=sn-5uaezn6y%2Csn-5goeen7k&ms=au%2Conr&mv=m&mvi=4&pl=20&pcm2=no&gcr=us&vprv=1&mime=video%2Fmp4&ns=RLzZDvY_Z38bokgXXbRQPcsF&gir=yes&clen=9420863&dur=168.459&lmt=1537605816427588&mt=1612107883&fvip=4&keepalive=yes&c=WEB&n=7oVCchs192EAS4VT6&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cpcm2%2Cgcr%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl&lsig=AG3C_xAwRQIgDWpMhDuqjZe0Z3qTDIiNb5c5fOl0Mw10sU28pTXId1cCIQDgvlzAqdYbbKGbNmqexW-Ad61wq8CS_gdfh8sT4-KQFg%3D%3D&sig=AOq0QJ8wRQIgJl6WlSKiruVnC_CvnXTLg4Ef6cyFxD_XtJLE_dHZ2-gCIQDvnB_KpN7XMsA55Hh4KY5UpNOUdQNVvdXADRSNSs6xqw==&ratebypass=yes

# %%
import cv2

input_movie = cv2.VideoCapture(url)
length = int(input_movie.get(cv2.CAP_PROP_FRAME_COUNT))
print(length)
# Out:
# 4039

# %%
from google.colab.patches import cv2_imshow
from IPython.display import clear_output
import time

frame_width = int(input_movie.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(input_movie.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(frame_width, frame_height)

frame_number = 0
frame_limit = 1000
# Define the codec and create VideoWriter object
#fourcc = cv2.VideoWriter_fourcc(*'FFV1')
fourcc = cv2.VideoWriter_fourcc(*'XVID')
#fourcc = cv2.VideoWriter_fourcc(*'DIVX')
#fourcc = cv2.VideoWriter_fourcc(*'DIV3')
#fourcc = cv2.VideoWriter_fourcc('F','M','P','4')
#fourcc = cv2.VideoWriter_fourcc('D','I','V','X')
#fourcc = cv2.VideoWriter_fourcc('D','I','V','3')
#fourcc = cv2.VideoWriter_fourcc('F','F','V','1')

filename = f"{video}.avi"
out = cv2.VideoWriter(filename,fourcc, 20.0, (frame_width,frame_height))
while True:
    ret, frame = input_movie.read()
    frame_number += 1

    if not ret or frame_number > frame_limit:
        break  
    out.write(frame)
    if frame_number < 10:
        cv2_imshow(frame)    
input_movie.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 854 462
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE6691616A0>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315B70>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315AC8>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315BA8>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315B70>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315BA8>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315B70>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315BA8>
# <PIL.Image.Image image mode=RGB size=854x462 at 0x7FE669315B70>

# %%
from google.colab import files
files.download(filename)
